# %% [markdown]
# ### __Group Assignment - Predicting Airbnb Listing Prices in Melbourne, Australia__

# %% [markdown]
# ---
#
# **Kaggle Competition Ends:** Friday, 6 June 2025 @ 3:00pm (Week 13)
# **Assignment Due Date on iLearn:** Friday, 6 June 2025 @ 11.55pm (Week 13)
# **Total Marks:** 30
#
# **Overview:**
#
# - In the group assignment you will form a team of 3 students and participate in a forecasting competition on Kaggle
# - The goal is to predict prices of used cars based on car characteristics and regression models

# %% [markdown]
# **Instructions:**
#
# - Form a team of 3 students
# - Each team member needs to join [https://www.kaggle.com](https://www.kaggle.com/)
# - Choose a team leader and form a team on Kaggle [https://www.kaggle.com/t/fc5974a56165cea945ee1ec182b079af](https://www.kaggle.com/t/fc5974a56165cea945ee1ec182b079af)
#     - Team leader to click on `team` and invite other 2 team members to join
#     - Your **team's name must start** with our unit code
# - All team members should work on all the tasks however
#     - Each team member will be responsible for one of the 3 tasks listed below
# - **Your predictions must be generated by a model you develop here**
#     - You will receive a mark of **zero** if your code is not able produce the forecasts you submit to Kaggle

# %% [markdown]
# **Competition Rankings**
#
# The rankings for the competition are determined through two different leaderboards:
#
# - **Public Leaderboard Ranking**: Available during the competition, these rankings are calculated based on 50% of the test dataset, which includes 1,500 observations. This allows participants to see how they are performing while the competition is still ongoing.
# - **Final Leaderboard Ranking**: These rankings are recalculated from the other 50% of the test dataset, which consists of the remaining 1,500 observations, and are revealed 5 minutes after the competition concludes. This final evaluation determines the ultimate standings of the competition.
#
#
#
# **Marks**
#
# - Assignment: 30 marks consisting of Solutions (27 marks) + Video Presentation (3 marks)
# - **Each Student's Mark: 50% x overall assignment mark + 50% x mark for the task that you are responsible for**

# %% [markdown]
# **Submissions:**
#
# 1. On Kaggle: submit your team's forecast in order to be ranked by Kaggle
# 2. On iLearn **only team leader to submit** the assignment Jupyter notebook re-named to your team's name on Kaggle
#     - The Jupyter notebook must contain team members names/ID numbers, and the group name Kaggle
#     - One 15 minute video recording of your work
#         - 5 marks will be deducted from each Task for which there is no video presentation

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### <span style="background-color: yellow;">**Fill out the following information**
#
# - Team Name on Kaggle: `(BUSA3020JMJ)`
# - Team Leader and Team Member 1: `(insert here)`
# - Team Member 2: `(insert here)`
# - Team Member 3: `(insert here)`

# %% [markdown]
# ---
#
# ## Task 1: Problem Description and Initial Data Analysis
#
# - You must clearly explain all your answers in both the Markdown file and the recorded video.
#
# **Total Marks: 9**
#
# Based on the Competition Overview, datasets and additional information provided on Kaggle, along with insights gained from personal research of the topic, write **Problem Description** (about 500 words) focusing on the sections listed below:
# 1. Forecasting Problem - explain what we are trying to do and how it could be used in the real world, e.g. who and how may benefit from it (2 marks)
# 2. Evaluation Criteria - discuss the criterion that is used in this competition to assess forecasting performance, and its pros and cons. (2 marks)
# 3. Categorise all variables provided in the dataset according to their type; Hint: similar to what we had in Programming Task 1 (2 marks)
# 4. Missing Values - explain what you find for both the training and test datasets at this stage (2 marks)
# 5. Provide and discuss some interesting *univariate* data characteristics (e.g. summary statistics and plots) in the training dataset  (1 marks)
# - Hints:
#     - You should **not** discuss any specific predictive algorithms at this stage

# %% [markdown]
# Student in charge of this task: `(insert name here)`

# %% [markdown]
# `(Task 1, Text Here - insert more cells as required) \n`
# #1: Forecasting Problem:
# The purpose of this problem is to create a forecasting model which can estimate an AirBnB listing price within Melbourne, based on appropriately selected features within a regression model which can encapsulate what dictates a high or low listing price. This can be applied within the real world through property owners seeking to find an appropriate price to rent out their property on AirBnB, this maximising their potential earnings without pricing themselves out of the market with a high price, or simply not getting enough utility out of the property by utilizing a low price. Both of which are prevalent risks through adopting an uninformed guess. AirBnB themselves could utilize this model to find ensure optimal pricing, maximizing their revenue Finally, It is also possible for individuals seeking to rent a property on the AirBnB service to utilize the model to ensure they are getting a fair deal on a property based on its features.
#
# #2 Evaluation Criteria
# The criterion of Mean Absolute Error to assess forecasting performance has both pros and cons.
# Pros:
# Compared to mean squared error, the model is less sensitive to outliers, with an error of X simply contributing X to the mean squared error. If we were using mean squared error as our metric, an error of X would be amplified to X^2. This causing a large error to have a significant effect on the models reported error. Meaning the model would likely be too sensitive to outliers An example being an error of 100 being squared to 10000.
#
# Cons:
# Not utilizing a percentage based metric causes the severity of errors to be understated specifically on cheaper properties. This as MAE ignores the size of the principle, and is not a relative calculation unlike MAPE which would recognise the severity of an error more effectively. This as an error of 300 should be considered be more significant under a property listed for 500 dollars compared to 2500, due to the size of the error relative to the pricing (60% vs 12%). This meaning the metric may not be the most appropriate due to the commonly wide range of real estate rental prices.
#
# #3 Variable Types
# |Variable Kind|Number of Features|Feature Names
# | --- | --- | --- |
# | Numeric | 38 | ID, host_response_rate, host_acceptance_rate, host_listings_count, latitude, longitude, accomodates, bathrooms, bedrooms, beds, minimum_nights, maximum_nights, minimum_minimum_nights, maximum_minimum_nights, minimum_maximum_nights, maximum_maximum_nights, minimum_nights_avg_ntm, maximum_nights_avg_ntm, availability_30, availability_60, availability_90, availability_365, number_of_reviews, number_of_reviews_ltm, number_of_reviews_l30d, review_scores_rating, review_scores_accuracy, review_scores_cleanliness, review_scores_checkin, review_scores_communication, review_scores_location, review_scores_value, calculated_host_listings_count, calculated_host_listings_count_entire_homes, calculated_host_listings_count_private_rooms, calculated_host_listings_count_shared_rooms, reviews_per_month, price |
# | Categorical-Ordinal  | 2 |  host_response_time, host_is_superhost  |
# | Categorical-Nominal  | 18 | source, name, description, neighborhood_overview, host_name, host_location, host_about, host_neighbourhood, neighbourhood, neighbourhood_cleansed, property_type, room_type, amenities, instant_bookable, has_availability, host_verifications, host_has_profile_pic, host_identity_verified |
# | Date  | 3| host_since, first_review, last_review |
#
# #4 Missing Values
# Within both the training and test data set there is a large amount of missing data. for the training dataset, missing values are most present within categorical variables neighborhood overview , host location, host_about, host_neighborhood and neighbourhood. Within the test dataset, there is a much higher amount of missing values proportionally with the same variables. With the addition of host_response_rate and time, as well as host_acceptance_rate
#
# It is important to mention that missing values for both the train and test dataset are not features likely or appropriate to be included within the predictive model of AirBnB prices, being related mostly to the host rather than qualities of properties themselves. Beyond this however there is some key features where there is a considerable amount of missing values. This including bedrooms (378 training, 60 test), as well as review scores specifically within the test dataset.
#
# #5 Univariate Data Characteristics
# NEED TO BE EXPLAINED

# %%
#Task 1 code here, insert more cells if required
import pandas as pd
import numpy as np
df_test = pd.read_csv("test.csv")
df_train = pd.read_csv("train.csv")
pd.set_option('display.max_rows', None)
missingval_test = df_test.isnull().sum()

# %%
#Need to remove price 
missingtrain_df = df_train.isnull().sum()
combined_missing = pd.concat([missingtrain_df, missingval_test], axis = 1)
combined_missing = combined_missing.rename(columns = {0: 'Train', 1: 'Test'})
combined_missing
# Out:
#                                               Train    Test
# ID                                                0     0.0
# source                                            0     0.0
# name                                              1     0.0
# description                                      57    31.0
# neighborhood_overview                          1823  1424.0
# host_name                                         0     0.0
# host_since                                        0     0.0
# host_location                                  1280   770.0
# host_about                                     2270  1441.0
# host_response_time                                0   737.0
# host_response_rate                                0   737.0
# host_acceptance_rate                             63   658.0
# host_is_superhost                                 0     2.0
# host_neighbourhood                             3460  2066.0
# host_listings_count                               0     0.0
# host_verifications                                0     0.0
# host_has_profile_pic                              0     0.0
# host_identity_verified                            0     0.0
# neighbourhood                                  1823  1424.0
# neighbourhood_cleansed                          108    42.0
# latitude                                          0     0.0
# longitude                                         0     0.0
# property_type                                    84    39.0
# room_type                                       134    41.0
# accommodates                                      0     0.0
# bathrooms                                         6     0.0
# bedrooms                                        378    60.0
# beds                                             72    12.0
# amenities                                         0     0.0
# minimum_nights                                    0     0.0
# maximum_nights                                    0     0.0
# minimum_minimum_nights                           45    10.0
# maximum_minimum_nights                            0     0.0
# minimum_maximum_nights                            0     0.0
# maximum_maximum_nights                           45    10.0
# minimum_nights_avg_ntm                            0     0.0
# maximum_nights_avg_ntm                            0     0.0
# has_availability                                  0     0.0
# availability_30                                   0     0.0
# availability_60                                   0     0.0
# availability_90                                   0     0.0
# availability_365                                 47    20.0
# number_of_reviews                                 0     0.0
# number_of_reviews_ltm                             0     0.0
# number_of_reviews_l30d                            0     0.0
# first_review                                      0   263.0
# last_review                                       0   263.0
# review_scores_rating                              0   263.0
# review_scores_accuracy                           22   299.0
# review_scores_cleanliness                        22   299.0
# review_scores_checkin                            22   300.0
# review_scores_communication                      22   300.0
# review_scores_location                           22   300.0
# review_scores_value                              22   300.0
# instant_bookable                                  0     0.0
# calculated_host_listings_count                    0     0.0
# calculated_host_listings_count_entire_homes       0     0.0
# calculated_host_listings_count_private_rooms      0     0.0
# calculated_host_listings_count_shared_rooms       0     0.0
# reviews_per_month                                 0   263.0
# price                                             0     NaN

# %% [markdown]
# Within both the training and test data set there is a large amount of missing data. for the training dataset, missing values are most present within categorical variables neighborhood overview , host location, host_about, host_neighborhood and neighbourhood. Within the test dataset, there is a much higher amount of missing values proportionally with the same variables. With the addition of host_response_rate and time, as well as host_acceptance_rate
#
# It is important to mention that missing values for both the train and test dataset are not features likely or appropriate to be included within the predictive model of AirBnB prices, being related mostly to the host rather than qualities of properties themselves. Beyond this however there is some key features where there is a considerable amount of missing values. This including bedrooms (378 training, 60 test), as well as review scores specifically within the test dataset.

# %%
df_train['price'] = df_train['price'].str.replace('$', '')
df_train['price'] = df_train['price'].str.replace(',', '')

# %%
df_train['price'] = df_train['price'].astype(float)
print(df_train['price'].describe().round(2))
import matplotlib.pyplot as plt
# Out:
# count      7000.00
# mean        285.65
# std        2325.45
# min          25.00
# 25%         117.00
# 50%         172.00
# 75%         268.00
# max      145160.00
# Name: price, dtype: float64

# %%
q1 = df_train['price'].quantile(0.25)
q3 = df_train['price'].quantile(0.75)

IQR = q3 - q1

#Defining Bounds
lower_bound = q1 - 1.5* IQR
upper_bound = q3 + 1.5* IQR
print('Lower and Upper bound')
print(lower_bound, upper_bound)
price_no_outliers = df_train[df_train['price'] <500]['price']

bins = np.arange(25, 525, 50)
plt.hist(price_no_outliers, edgecolor = 'black', bins = bins)
plt.xticks([25, 75, 125, 175, 225, 275, 325, 375, 425, 475, 525])
plt.xlabel('Rental Cost Per Night ($)')
plt.ylabel('Count')
# Out:
# Lower and Upper bound
# -109.5 494.5
# Text(0, 0.5, 'Count')

# %%
print(df_train['bedrooms'].describe().round(2))
import matplotlib.pyplot as plt
bedroom_count = df_train['bedrooms'].value_counts()
plt.xlabel('Number of Bedrooms')
plt.ylabel('Frequency')
plt.xticks(range(0, 15, 1))
plt.bar(bedroom_count.index, bedroom_count.values)
# Out:
# count    6622.00
# mean        1.79
# std         1.06
# min         1.00
# 25%         1.00
# 50%         1.00
# 75%         2.00
# max        14.00
# Name: bedrooms, dtype: float64
# <BarContainer object of 11 artists>

# %%
print(df_train['accommodates'].describe().round(2))
import matplotlib.pyplot as plt
accommodates_count = df_train['accommodates'].value_counts()
plt.xlabel('Maxmimum People Accomodated')
plt.ylabel('Number of listings')
plt.xticks(range(0, 17, 1))

plt.bar(accommodates_count.index, accommodates_count.values)
# Out:
# count    7000.00
# mean        3.84
# std         2.51
# min         1.00
# 25%         2.00
# 50%         4.00
# 75%         5.00
# max        16.00
# Name: accommodates, dtype: float64
# <BarContainer object of 16 artists>

# %% [markdown]
# ---
#
# ## Task 2: Data Cleaning, Missing Observations and Feature Engineering
#
# - You must clearly explain all your answers in both the Markdown file and the recorded video.
#
# **Total Marks: 9**

# %% [markdown]
# Student in charge of this task: `(insert name here)`

# %% [markdown]
# **Task 2, Question 1**: Clean **all** numerical features so that they can be used in training algorithms. For instance, `host_response_rate` feature is in object format containing both numerical values and text. Extract numerical values (or equivalently eliminate the text) so that the numerical values can be used as a regular feature.
# (2 marks)

# %%
## Task 2, Question 1 Code Here
bath_map = {
    '0 baths': 0, 
    '0 shared baths': 0, 
    'Half-bath': 0.5, 
    'Private half-bath': 0.5, 
    'Shared half-bath': 0.5, 
    '1 bath': 1, 
    '1 private bath': 1,
    '1 shared bath': 1,
    '1.5 baths': 1.5,
    '1.5 shared baths': 1.5,
    '2 baths': 2,
    '2 shared baths': 2,
    '2.5 baths': 2.5,
    '2.5 shared baths': 2.5, 
    '3 baths': 3,
    '3 shared baths': 3,
    '3.5 baths': 3.5,
    '3.5 shared baths': 3.5,
    '4 baths': 4,
    '4 shared baths': 4,
    '4.5 baths': 4.5,
    '5 baths': 5, 
    '5 shared baths': 5,
    '5.5 baths': 5.5,
    '5.5 shared baths': 5.5,
    '6 baths': 6,
    '6.5 baths': 6.5,
    '8.5 baths': 8.5,
    '9 baths': 9,
    '9.5 baths': 9.5,
    '10 baths': 10}  

df_train['bathrooms'] = df_train['bathrooms'].map(bath_map)
df_test['bathrooms'] = df_test['bathrooms'].map(bath_map)

#df_test['bathrooms'] = df_test['bathrooms'].map(bath_map)

#Mapping Response Rate & Changing to float for imputation
df_train['host_response_rate'] = df_train['host_response_rate'].str.replace('%', '').astype(float)
df_test['host_response_rate'] = df_test['host_response_rate'].str.replace('%', '').astype(float)
#Mapping Acceptance Rate
df_train['host_acceptance_rate'] = df_train['host_acceptance_rate'].str.replace('%', '').astype(float)
df_test['host_acceptance_rate'] = df_test['host_acceptance_rate'].str.replace('%', '').astype(float)


#Price Variable Was cleaned in section 1

# %% [markdown]
# Within my first function, I created the mapping for our 'bathrooms' feature, storing the mapping within bath_map, reassigning each category to a integer. I then used df_train/test['bathrooms'].map(bath_map) in order to apply this replacement. Altering the column to a numeric variable appropriate for being used as a regular feature.
#
# Similarly, I also altered host_response_rate as well as host_acceptance rate in order to be used as a regular numeric feature, this though using str.replace on the respective columns to replace their percentage symbols '%' to a blank space ''. I then converted these variables to a float as they were currently stored as a string due to the inclusion of the percentage symbols

# %% [markdown]
# **Task 2, Question 2** Create at least 4 new features from existing features which contain multiple items of information.
# (2 marks)

# %%
## Task 2, Question 2 Code Here
#Feature 'has_gym' 
df_train['has_gym'] = df_train['amenities'].str.contains('gym', case=False).astype(int)
df_test['has_gym'] = df_test['amenities'].str.contains('gym', case=False).astype(int)

#Feature 'has_hot_tub'
df_train['has_hot_tub'] = df_train['amenities'].str.contains('hot tub', case=False).astype(int)
df_test['has_hot_tub'] = df_test['amenities'].str.contains('hot tub', case=False).astype(int)

# days since first review
df_train['first_review'] = pd.to_datetime(df_train['first_review'], errors='coerce')
df_train['days_since_first_review'] = (pd.Timestamp.today() - df_train['first_review']).dt.days

df_test['first_review'] = pd.to_datetime(df_test['first_review'], errors='coerce')
df_test['days_since_first_review'] = (pd.Timestamp.today() - df_test['first_review']).dt.days


# count amount of amenities each listing
df_train['amenities_count'] = df_train['amenities'].str.count(',') + 1
df_test['amenities_count'] = df_test['amenities'].str.count(',') + 1

# new feature that measures how long the listing has been receiving reviews (in years)
# This is calculated as the difference between the last and first review dates
df_train['first_review'] = pd.to_datetime(df_test['first_review'], errors='coerce', dayfirst=True)
df_train['last_review'] = pd.to_datetime(df_test['last_review'], errors='coerce', dayfirst=True)
df_train['years_of_review_activity'] = ((df_train['last_review'] - df_test['first_review']).dt.days / 365).round(2)

df_test['first_review'] = pd.to_datetime(df_test['first_review'], errors='coerce', dayfirst=True)
df_test['last_review'] = pd.to_datetime(df_test['last_review'], errors='coerce', dayfirst=True)
df_test['years_of_review_activity'] = ((df_test['last_review'] - df_test['first_review']).dt.days / 365).round(2)
# Out:
# C:\Users\Jett\AppData\Local\Temp\ipykernel_56616\403744414.py:11: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_train['first_review'] = pd.to_datetime(df_train['first_review'], errors='coerce')

# %% [markdown]
# Creating new features, I first derived two new features from the ameneties feature, originally being a list of different commodoties provided within AirBnB listings. First, i selected the amenity gym, as I believe it is a good indicator of a high quality or luxury property and is likely correlated with higher pricing. I undertook this through str.contains, creating a binary variable with observations which included 'gym' within their amenities.
# I undertook this same process when creating the variable 'has_hot_tub', being another indicator of luxury and estimator of high priced listings. To ensure that these variables were appropriate to include within the model, I also calculated the value counts of each of these new variables in the training dataset. This showing over 1500 listings with gyms, and approximately 700 listings with hot tubs. This showing they were necessary inclusions within our model.
#
# ##Need to explain days since first review

# %% [markdown]
# **Task 2, Question 3**: Impute the missing values for all features in both the training and test datasets.
# (2 marks)

# %%
## Task 2, Question 3 Code Here
#Importing SimpleImputer
from sklearn.impute import SimpleImputer

num_columns =  df_train.select_dtypes(include='number').columns

cat_columns = df_train.select_dtypes(include='object').columns

date_columns = df_train.select_dtypes(include='datetime').columns

df_train.fillna(df_train[num_columns].mean(), inplace=True)
df_train.fillna(df_train[cat_columns].mode().iloc[0], inplace=True)
df_train.fillna(df_train[date_columns].mean(), inplace=True)

df_test.fillna(df_train[num_columns].mean(), inplace=True)
df_test.fillna(df_train[cat_columns].mode().iloc[0], inplace=True)
df_test.fillna(df_train[date_columns].mean(), inplace=True)

#print(df_train.isnull().sum())
#print(df_test.isnull().sum())

# %% [markdown]
# `(Task 2, Question 3 Text Here - insert more cells as required)`

# %% [markdown]
# **Task 2, Question 4**: Encode all categorical variables appropriately as discussed in class.
#
# - Where multiple values are given for an observation encode the observation as 'other'.
# - Where a categorical feature contains more than 5 unique values, map the features into 5 most frequent values + 'other' and then encode appropriately.
# (2 marks)

# %%
## Task 2, Question 4 Code Here
#Finding 5 most freqent categories in training columns
import numpy as np
top5={col: df_train[col].value_counts().nlargest(5).index
    for col in cat_columns
     }

#Encoding Variables within Train Dataset
for col in cat_columns:
    df_train[col] = df_train[col].where(df_train[col].isin(top5[col]), 'Other')
    
df_train = pd.get_dummies(df_train, columns=cat_columns, drop_first=True)

#Encoding Variables within Test Dataset
for col in cat_columns:
    df_test[col] = df_test[col].where(df_test[col].isin(top5[col]), 'Other')

df_test = pd.get_dummies(df_test, columns=cat_columns, drop_first=True)

# %%
#df_test_encoded

# %% [markdown]
# `(Task 2, Question 4 Text Here - insert more cells as required)`

# %% [markdown]
# **Task 2, Question 5**: Perform any additional data preparation steps you consider necessary before building your predictive models, and clearly explain each action you take.
# (1 mark)

# %%
## Task 2, Question 5 Code Here
#Removing Unuseful Variables
df_train=df_train.drop(['neighborhood_overview'], axis=1)
df_train=df_train.drop(['description'], axis=1)
df_train=df_train.drop(['neighbourhood'], axis=1)
df_train=df_train.drop(['source'], axis=1)

df_test=df_test.drop(['neighborhood_overview'], axis=1)
df_test=df_test.drop(['description'], axis=1)
df_test=df_test.drop(['neighbourhood'], axis=1)
df_test=df_test.drop(['source'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[88], line 3
#       1 ## Task 2, Question 5 Code Here
#       2 #Removing Unuseful Variables
# ----> 3 df_train=df_train.drop(['neighborhood_overview'], axis=1)
#       4 df_train=df_train.drop(['description'], axis=1)
#       5 df_train=df_train.drop(['neighbourhood'], axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['neighborhood_overview'] not found in axis"

# %%
df_train['log_price'] = np.log1p(df_train['price'])
#df_test['log_price'] = np.log1p(df_test['price'])

# %% [markdown]
# `(Task 2, Question 5 Text Here - insert more cells as required)`

# %% [markdown]
# ---
# ## Task 3: Fit and tune predictive models, submit predictions & win competition
#
# - You must clearly explain all your answers in both the Markdown file and the recorded video.
# -
# **Total Marks: 9**
#
# For this task, you should not create any new features and must rely on the variables constructed in Task 2.
#
#
# 1. Perform some EDA to measure the relationship between the features and the target variable, and carefully explain your findings. (2 marks)
#
# 2. Choose and carefully explain 3 different machine learning (ML) regression models that you will apply in this competition. (2 marks)
#
# 3. Train the models from the above question and tune their hyperparameters via cross-validation. Discuss the fitted weights, optimised hyperparameter values, and their training dataset predictive performance. (2 marks)
#
# 4. Select your best model, create predictions of the test dataset and submit your forecasts on Kaggle's competition page. Provide Kaggle ranking and score (screenshots) and comment on your performance in the competition. (2 marks)
#
# 5. Suggest ways to improve your ranking and implement them, providing further evidence from Kaggle (screenshots). (1 mark)
#
# - Hints:
#     - Make sure your Python code works so that your results can be replicated by the marker
#     - You will receive the mark of zero for this Task if your code does not produce the forecasts uploaded to Kaggle

# %% [markdown]
# Student in charge of this task: `(insert name here)`

# %%
#Task 3 code here
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
df_train.describe()
# Out:
#                 ID  host_response_rate  host_acceptance_rate  \
# count  7000.000000         7000.000000           7000.000000
# mean   3499.500000           96.009571             88.536255
# min       0.000000            0.000000              0.000000
# 25%    1749.750000          100.000000             88.536255
# 50%    3499.500000          100.000000             97.000000
# 75%    5249.250000          100.000000            100.000000
# max    6999.000000          100.000000            100.000000
# std    2020.870275           13.795023             20.479608
#
#        host_listings_count     latitude    longitude  accommodates  \
# count          7000.000000  7000.000000  7000.000000   7000.000000
# mean             15.625571   -37.826139   145.039399      3.839714
# min               1.000000   -38.224110   144.517800      1.000000
# 25%               1.000000   -37.856415   144.956993      2.000000
# 50%               3.000000   -37.818565   144.980060      4.000000
# 75%               9.000000   -37.800105   145.056391      5.000000
# max             292.000000   -37.486450   145.831410     16.000000
# std              41.600059     0.080672     0.181751      2.514657
#
#         bathrooms     bedrooms         beds  ...  \
# count  7000.00000  7000.000000  7000.000000  ...
# mean      1.37525     1.785865     2.263568  ...
# min       0.00000     1.000000     1.000000  ...
# 25%       1.00000     1.000000     1.000000  ...
# 50%       1.00000     1.785865     2.000000  ...
# 75%       2.00000     2.000000     3.000000  ...
# max      10.00000    14.000000    22.000000  ...
# std       0.68675     1.027439     1.774014  ...
#
#        calculated_host_listings_count_private_rooms  \
# count                                   7000.000000
# mean                                       4.270429
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        1.000000
# max                                      224.000000
# std                                       28.316711
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month  \
# count                                  7000.000000        7000.000000
# mean                                      0.030286           1.465427
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.400000
# 50%                                       0.000000           1.000000
# 75%                                       0.000000           2.050000
# max                                       6.000000          34.090000
# std                                       0.309302           1.630973
#
#                price      has_gym  has_hot_tub  days_since_first_review  \
# count    7000.000000  7000.000000  7000.000000              7000.000000
# mean      285.649714     0.220714     0.099571              2282.814143
# min        25.000000     0.000000     0.000000               818.000000
# 25%       117.000000     0.000000     0.000000              1536.000000
# 50%       172.000000     0.000000     0.000000              2204.500000
# 75%       268.000000     0.000000     0.000000              2896.250000
# max    145160.000000     1.000000     1.000000              5379.000000
# std      2325.453324     0.414758     0.299449               859.433165
#
#        amenities_count  years_of_review_activity    log_price
# count      7000.000000               7000.000000  7000.000000
# mean         36.464429                  0.908481     5.192391
# min           1.000000                 -0.870000     3.258097
# 25%          26.000000                  0.908481     4.770685
# 50%          35.000000                  0.908481     5.153292
# 75%          46.000000                  0.908481     5.594711
# max         134.000000                  7.780000    11.885599
# std          14.913338                  0.361689     0.687083
#
# [8 rows x 46 columns]

# %%
#print(df_train.dtypes)
df_train = df_train.drop(columns=df_train.select_dtypes(include='object').columns)

# %%
from sklearn.linear_model import LinearRegression
df_train.corr()
# Out:
#                                                           ID  \
# ID                                                  1.000000
# host_response_rate                                  0.043111
# host_acceptance_rate                                0.107747
# host_listings_count                                 0.106085
# latitude                                            0.011285
# longitude                                           0.013168
# accommodates                                        0.065331
# bathrooms                                           0.056394
# bedrooms                                            0.065317
# beds                                                0.034310
# minimum_nights                                     -0.035845
# maximum_nights                                     -0.016394
# minimum_minimum_nights                             -0.048126
# maximum_minimum_nights                             -0.031778
# minimum_maximum_nights                              0.009421
# maximum_maximum_nights                              0.030060
# minimum_nights_avg_ntm                             -0.038600
# maximum_nights_avg_ntm                              0.030071
# availability_30                                     0.143130
# availability_60                                     0.144180
# availability_90                                     0.135360
# availability_365                                   -0.011901
# number_of_reviews                                  -0.357456
# number_of_reviews_ltm                               0.070844
# number_of_reviews_l30d                              0.027147
# first_review                                       -0.158146
# last_review                                        -0.098272
# review_scores_rating                               -0.081644
# review_scores_accuracy                             -0.132776
# review_scores_cleanliness                          -0.125360
# review_scores_checkin                              -0.146122
# review_scores_communication                        -0.140471
# review_scores_location                             -0.065824
# review_scores_value                                -0.138333
# calculated_host_listings_count                      0.093259
# calculated_host_listings_count_entire_homes         0.136694
# calculated_host_listings_count_private_rooms        0.041809
# calculated_host_listings_count_shared_rooms         0.030876
# reviews_per_month                                   0.109454
# price                                               0.008676
# has_gym                                             0.078304
# has_hot_tub                                        -0.018277
# days_since_first_review                            -0.889492
# amenities_count                                     0.037625
# years_of_review_activity                            0.000782
# source_previous scrape                             -0.033956
# name_Domi Rentals - The Carlisle Apartments        -0.035006
# name_Large Room in our Lovely Carlton Guest House  -0.012567
# name_One Bedroom Apartment                          0.020629
# name_Other                                         -0.011427
# name_墨尔本东北区Bundoora温馨独栋别墅，房间干净整齐、设施齐全、交通方便、高速网络...  0.017479
# description_Hotel like room for 1 person with e...  0.054428
# description_Hotel like room for 1 person with e... -0.025647
# description_Large and beautiful private room fo... -0.007104
# description_Other                                  -0.028511
# description_The moment you step into our apartm...  0.004981
# neighborhood_overview_Melbourne - Voted most li...  0.197045
# neighborhood_overview_Other                        -0.192702
# neighborhood_overview_So why not check out Melb...  0.016227
# neighborhood_overview_The best part of the area... -0.012680
# neighborhood_overview_The property is centrally... -0.029531
# host_name_James                                    -0.002548
# host_name_Other                                     0.018411
# host_name_Paul & Dan                               -0.018776
# host_name_S&S                                      -0.044988
# host_name_Valeria                                   0.040266
# host_since_19/01/2016                               0.039804
# host_since_19/08/2016                               0.039621
# host_since_29/09/2015                               0.002635
# host_since_30/06/2011                              -0.044029
# host_since_Other                                   -0.014736
# host_location_Healesville, Australia               -0.054209
# host_location_Melbourne, Australia                  0.113352
# host_location_Other                                -0.040039
# host_location_South Yarra, Australia                0.016128
# host_location_Victoria, Australia                  -0.106716
# host_about_Hello everybody!\r\n\r\nWe aim to ma... -0.036907
# host_about_Hi there! We are Paul and Dan and ru... -0.018776
# host_about_Love cooking, running, playing piano...  0.039804
# host_about_Other                                   -0.196529
# host_about_We specialise in offering a new and ...  0.210449
# host_response_time_within a day                    -0.083386
# host_response_time_within a few hours              -0.055248
# host_response_time_within an hour                   0.112460
# host_is_superhost_t                                -0.070688
# host_neighbourhood_Central Business District        0.244285
# host_neighbourhood_Other                           -0.203565
# host_neighbourhood_South Yarra                     -0.044831
# host_neighbourhood_Southbank                       -0.009105
# host_neighbourhood_St Kilda                        -0.104781
# host_verifications_['email', 'phone']              -0.042597
# host_verifications_['email']                       -0.002996
# host_verifications_['phone', 'work_email']         -0.014590
# host_verifications_['phone']                        0.120452
# host_has_profile_pic_t                             -0.071496
# host_identity_verified_t                            0.009649
# neighbourhood_Docklands, Victoria, Australia        0.035510
# neighbourhood_Melbourne, Victoria, Australia        0.199052
# neighbourhood_Other                                -0.180825
# neighbourhood_South Yarra, Victoria, Australia     -0.046777
# neighbourhood_Southbank, Victoria, Australia       -0.025372
# neighbourhood_cleansed_Other                       -0.006185
# neighbourhood_cleansed_Port Phillip                -0.071449
# neighbourhood_cleansed_Stonnington                 -0.030956
# neighbourhood_cleansed_Yarra                       -0.055026
# neighbourhood_cleansed_Yarra Ranges                 0.007788
# property_type_Entire home                          -0.005754
# property_type_Entire rental unit                   -0.001671
# property_type_Entire serviced apartment             0.137127
# property_type_Other                                 0.006311
# property_type_Private room in home                 -0.082420
# room_type_Hotel room                               -0.006188
# room_type_Private room                             -0.076366
# room_type_Shared room                               0.025499
# amenities_["Building staff", "Essentials", "Smo...  0.052685
# amenities_["Essentials", "Smoke alarm", "Hair d... -0.022753
# amenities_["Essentials", "Smoke alarm", "Hot wa... -0.001242
# amenities_["Extra pillows and blankets", "Micro...  0.022532
# amenities_["Microwave", "Essentials", "Smoke al... -0.007245
# instant_bookable_t                                  0.082260
# log_price                                           0.099608
#
#                                                     host_response_rate  \
# ID                                                            0.043111
# host_response_rate                                            1.000000
# host_acceptance_rate                                          0.427032
# host_listings_count                                          -0.000048
# latitude                                                      0.004535
# longitude                                                     0.065148
# accommodates                                                  0.082843
# bathrooms                                                     0.030385
# bedrooms                                                      0.053545
# beds                                                          0.073438
# minimum_nights                                               -0.053619
# maximum_nights                                               -0.016506
# minimum_minimum_nights                                       -0.071707
# maximum_minimum_nights                                       -0.049225
# minimum_maximum_nights                                       -0.004340
# maximum_maximum_nights                                       -0.058342
# minimum_nights_avg_ntm                                       -0.058395
# maximum_nights_avg_ntm                                       -0.058239
# availability_30                                              -0.112995
# availability_60                                              -0.090859
# availability_90                                              -0.077827
# availability_365                                             -0.050063
# number_of_reviews                                             0.109985
# number_of_reviews_ltm                                         0.158443
# number_of_reviews_l30d                                        0.150317
# first_review                                                  0.017507
# last_review                                                  -0.003813
# review_scores_rating                                          0.234304
# review_scores_accuracy                                        0.173016
# review_scores_cleanliness                                     0.150597
# review_scores_checkin                                         0.166710
# review_scores_communication                                   0.194843
# review_scores_location                                        0.151502
# review_scores_value                                           0.149639
# calculated_host_listings_count                               -0.000941
# calculated_host_listings_count_entire_homes                   0.035622
# calculated_host_listings_count_private_rooms                 -0.020409
# calculated_host_listings_count_shared_rooms                  -0.009779
# reviews_per_month                                             0.134960
# price                                                         0.003349
# has_gym                                                      -0.025466
# has_hot_tub                                                  -0.012509
# days_since_first_review                                      -0.018410
# amenities_count                                               0.210671
# years_of_review_activity                                     -0.015066
# source_previous scrape                                       -0.021480
# name_Domi Rentals - The Carlisle Apartments                   0.008862
# name_Large Room in our Lovely Carlton Guest House            -0.004267
# name_One Bedroom Apartment                                   -0.039258
# name_Other                                                    0.012968
# name_墨尔本东北区Bundoora温馨独栋别墅，房间干净整齐、设施齐全、交通方便、高速网络...            0.009153
# description_Hotel like room for 1 person with e...            0.004991
# description_Hotel like room for 1 person with e...           -0.004609
# description_Large and beautiful private room fo...           -0.004928
# description_Other                                            -0.002508
# description_The moment you step into our apartm...            0.008473
# neighborhood_overview_Melbourne - Voted most li...           -0.101440
# neighborhood_overview_Other                                   0.098514
# neighborhood_overview_So why not check out Melb...           -0.015665
# neighborhood_overview_The best part of the area...            0.018001
# neighborhood_overview_The property is centrally...           -0.006973
# host_name_James                                               0.014663
# host_name_Other                                               0.055844
# host_name_Paul & Dan                                          0.027568
# host_name_S&S                                                -0.131361
# host_name_Valeria                                            -0.018745
# host_since_19/01/2016                                         0.024537
# host_since_19/08/2016                                        -0.017938
# host_since_29/09/2015                                         0.018658
# host_since_30/06/2011                                         0.024783
# host_since_Other                                             -0.028451
# host_location_Healesville, Australia                          0.016007
# host_location_Melbourne, Australia                           -0.013320
# host_location_Other                                          -0.008575
# host_location_South Yarra, Australia                          0.002535
# host_location_Victoria, Australia                             0.018890
# host_about_Hello everybody!\r\n\r\nWe aim to ma...           -0.107169
# host_about_Hi there! We are Paul and Dan and ru...            0.027568
# host_about_Love cooking, running, playing piano...            0.024537
# host_about_Other                                              0.085975
# host_about_We specialise in offering a new and ...           -0.085247
# host_response_time_within a day                              -0.164857
# host_response_time_within a few hours                         0.039139
# host_response_time_within an hour                             0.323129
# host_is_superhost_t                                           0.208488
# host_neighbourhood_Central Business District                 -0.017061
# host_neighbourhood_Other                                     -0.001050
# host_neighbourhood_South Yarra                                0.010866
# host_neighbourhood_Southbank                                  0.027878
# host_neighbourhood_St Kilda                                   0.010521
# host_verifications_['email', 'phone']                        -0.026729
# host_verifications_['email']                                  0.003458
# host_verifications_['phone', 'work_email']                    0.005981
# host_verifications_['phone']                                 -0.023443
# host_has_profile_pic_t                                        0.000032
# host_identity_verified_t                                      0.147515
# neighbourhood_Docklands, Victoria, Australia                  0.013538
# neighbourhood_Melbourne, Victoria, Australia                 -0.085307
# neighbourhood_Other                                           0.069445
# neighbourhood_South Yarra, Victoria, Australia                0.014555
# neighbourhood_Southbank, Victoria, Australia                  0.028489
# neighbourhood_cleansed_Other                                 -0.031109
# neighbourhood_cleansed_Port Phillip                          -0.022552
# neighbourhood_cleansed_Stonnington                           -0.010699
# neighbourhood_cleansed_Yarra                                  0.040736
# neighbourhood_cleansed_Yarra Ranges                           0.068821
# property_type_Entire home                                     0.030800
# property_type_Entire rental unit                              0.064280
# property_type_Entire serviced apartment                      -0.069422
# property_type_Other                                          -0.026312
# property_type_Private room in home                           -0.073646
# room_type_Hotel room                                         -0.115905
# room_type_Private room                                       -0.114272
# room_type_Shared room                                        -0.029415
# amenities_["Building staff", "Essentials", "Smo...           -0.005227
# amenities_["Essentials", "Smoke alarm", "Hair d...            0.009153
# amenities_["Essentials", "Smoke alarm", "Hot wa...           -0.005227
# amenities_["Extra pillows and blankets", "Micro...           -0.000020
# amenities_["Microwave", "Essentials", "Smoke al...            0.011477
# instant_bookable_t                                            0.041954
# log_price                                                     0.029720
#
#                                                     host_acceptance_rate  \
# ID                                                              0.107747
# host_response_rate                                              0.427032
# host_acceptance_rate                                            1.000000
# host_listings_count                                            -0.249739
# latitude                                                       -0.013115
# longitude                                                       0.089813
# accommodates                                                    0.118022
# bathrooms                                                      -0.057105
# bedrooms                                                        0.062375
# beds                                                            0.072236
# minimum_nights                                                 -0.054286
# maximum_nights                                                  0.040552
# minimum_minimum_nights                                         -0.078138
# maximum_minimum_nights                                         -0.037768
# minimum_maximum_nights                                         -0.004396
# maximum_maximum_nights                                          0.009684
# minimum_nights_avg_ntm                                         -0.057122
# maximum_nights_avg_ntm                                          0.009691
# availability_30                                                -0.032950
# availability_60                                                -0.025879
# availability_90                                                -0.025442
# availability_365                                                0.036984
# number_of_reviews                                               0.219438
# number_of_reviews_ltm                                           0.287087
# number_of_reviews_l30d                                          0.231710
# first_review                                                   -0.045599
# last_review                                                    -0.027526
# review_scores_rating                                            0.110587
# review_scores_accuracy                                          0.076247
# review_scores_cleanliness                                       0.096747
# review_scores_checkin                                           0.020993
# review_scores_communication                                     0.067835
# review_scores_location                                          0.068372
# review_scores_value                                             0.046120
# calculated_host_listings_count                                 -0.269205
# calculated_host_listings_count_entire_homes                    -0.055032
# calculated_host_listings_count_private_rooms                   -0.337492
# calculated_host_listings_count_shared_rooms                     0.028495
# reviews_per_month                                               0.259810
# price                                                           0.012488
# has_gym                                                         0.046203
# has_hot_tub                                                    -0.012730
# days_since_first_review                                        -0.070148
# amenities_count                                                 0.253379
# years_of_review_activity                                       -0.003938
# source_previous scrape                                         -0.036146
# name_Domi Rentals - The Carlisle Apartments                     0.013579
# name_Large Room in our Lovely Carlton Guest House              -0.076572
# name_One Bedroom Apartment                                      0.004689
# name_Other                                                      0.053350
# name_墨尔本东北区Bundoora温馨独栋别墅，房间干净整齐、设施齐全、交通方便、高速网络...              0.016166
# description_Hotel like room for 1 person with e...             -0.064228
# description_Hotel like room for 1 person with e...             -0.082713
# description_Large and beautiful private room fo...             -0.088430
# description_Other                                               0.094289
# description_The moment you step into our apartm...              0.010675
# neighborhood_overview_Melbourne - Voted most li...             -0.063368
# neighborhood_overview_Other                                     0.066558
# neighborhood_overview_So why not check out Melb...              0.024147
# neighborhood_overview_The best part of the area...              0.031796
# neighborhood_overview_The property is centrally...             -0.125131
# host_name_James                                                 0.033186
# host_name_Other                                                 0.211443
# host_name_Paul & Dan                                            0.048695
# host_name_S&S                                                  -0.062545
# host_name_Valeria                                              -0.336377
# host_since_19/01/2016                                           0.043340
# host_since_19/08/2016                                          -0.332369
# host_since_29/09/2015                                           0.024722
# host_since_30/06/2011                                           0.031224
# host_since_Other                                                0.140132
# host_location_Healesville, Australia                            0.030722
# host_location_Melbourne, Australia                              0.033167
# host_location_Other                                             0.027809
# host_location_South Yarra, Australia                            0.032034
# host_location_Victoria, Australia                              -0.113701
# host_about_Hello everybody!\r\n\r\nWe aim to ma...             -0.048835
# host_about_Hi there! We are Paul and Dan and ru...              0.048695
# host_about_Love cooking, running, playing piano...              0.043340
# host_about_Other                                                0.074622
# host_about_We specialise in offering a new and ...             -0.091436
# host_response_time_within a day                                -0.317059
# host_response_time_within a few hours                          -0.284711
# host_response_time_within an hour                               0.530574
# host_is_superhost_t                                             0.273716
# host_neighbourhood_Central Business District                    0.066168
# host_neighbourhood_Other                                       -0.000973
# host_neighbourhood_South Yarra                                 -0.007673
# host_neighbourhood_Southbank                                    0.054655
# host_neighbourhood_St Kilda                                     0.017761
# host_verifications_['email', 'phone']                           0.010317
# host_verifications_['email']                                    0.006691
# host_verifications_['phone', 'work_email']                      0.018652
# host_verifications_['phone']                                   -0.019735
# host_has_profile_pic_t                                          0.000610
# host_identity_verified_t                                        0.115206
# neighbourhood_Docklands, Victoria, Australia                    0.047275
# neighbourhood_Melbourne, Victoria, Australia                    0.002913
# neighbourhood_Other                                            -0.012553
# neighbourhood_South Yarra, Victoria, Australia                  0.015371
# neighbourhood_Southbank, Victoria, Australia                    0.054701
# neighbourhood_cleansed_Other                                   -0.086915
# neighbourhood_cleansed_Port Phillip                            -0.031249
# neighbourhood_cleansed_Stonnington                             -0.002581
# neighbourhood_cleansed_Yarra                                    0.009343
# neighbourhood_cleansed_Yarra Ranges                             0.088418
# property_type_Entire home                                      -0.002478
# property_type_Entire rental unit                                0.121674
# property_type_Entire serviced apartment                         0.014630
# property_type_Other                                             0.014247
# property_type_Private room in home                             -0.230840
# room_type_Hotel room                                            0.002171
# room_type_Private room                                         -0.229051
# room_type_Shared room                                          -0.006307
# amenities_["Building staff", "Essentials", "Smo...             -0.032478
# amenities_["Essentials", "Smoke alarm", "Hair d...              0.017711
# amenities_["Essentials", "Smoke alarm", "Hot wa...             -0.093801
# amenities_["Extra pillows and blankets", "Micro...              0.016396
# amenities_["Microwave", "Essentials", "Smoke al...              0.012522
# instant_bookable_t                                              0.246914
# log_price                                                       0.139344
#
#                                                     host_listings_count  \
# ID                                                             0.106085
# host_response_rate                                            -0.000048
# host_acceptance_rate                                          -0.249739
# host_listings_count                                            1.000000
# latitude                                                       0.028119
# longitude                                                     -0.103399
# accommodates                                                  -0.014715
# bathrooms                                                      0.190360
# bedrooms                                                      -0.018629
# beds                                                           0.005472
# minimum_nights                                                 0.020341
# maximum_nights                                                 0.026828
# minimum_minimum_nights                                         0.016763
# maximum_minimum_nights                                         0.025343
# minimum_maximum_nights                                        -0.003629
# maximum_maximum_nights                                        -0.010117
# minimum_nights_avg_ntm                                         0.026830
# maximum_nights_avg_ntm                                        -0.010132
# availability_30                                                0.091885
# availability_60                                                0.125083
# availability_90                                                0.115143
# availability_365                                              -0.094254
# number_of_reviews                                             -0.113059
# number_of_reviews_ltm                                         -0.085129
# number_of_reviews_l30d                                        -0.102705
# first_review                                                  -0.001970
# last_review                                                   -0.000157
# review_scores_rating                                          -0.142832
# review_scores_accuracy                                        -0.163688
# review_scores_cleanliness                                     -0.216259
# review_scores_checkin                                         -0.132527
# review_scores_communication                                   -0.165374
# review_scores_location                                        -0.050165
# review_scores_value                                           -0.181228
# calculated_host_listings_count                                 0.958030
# calculated_host_listings_count_entire_homes                    0.742594
# calculated_host_listings_count_private_rooms                   0.853447
# calculated_host_listings_count_shared_rooms                    0.001248
# reviews_per_month                                             -0.090200
# price                                                         -0.006003
# has_gym                                                        0.044042
# has_hot_tub                                                   -0.063140
# days_since_first_review                                       -0.132714
# amenities_count                                               -0.149800
# years_of_review_activity                                       0.015867
# source_previous scrape                                        -0.028560
# name_Domi Rentals - The Carlisle Apartments                    0.039027
# name_Large Room in our Lovely Carlton Guest House              0.194602
# name_One Bedroom Apartment                                    -0.009149
# name_Other                                                    -0.193455
# name_墨尔本东北区Bundoora温馨独栋别墅，房间干净整齐、设施齐全、交通方便、高速网络...             0.001806
# description_Hotel like room for 1 person with e...             0.142101
# description_Hotel like room for 1 person with e...             0.210209
# description_Large and beautiful private room fo...             0.224739
# description_Other                                             -0.242612
# description_The moment you step into our apartm...             0.015754
# neighborhood_overview_Melbourne - Voted most li...             0.023018
# neighborhood_overview_Other                                   -0.072929
# neighborhood_overview_So why not check out Melb...            -0.002723
# neighborhood_overview_The best part of the area...             0.097795
# neighborhood_overview_The property is centrally...             0.318011
# host_name_James                                                0.010898
# host_name_Other                                               -0.617306
# host_name_Paul & Dan                                           0.149772
# host_name_S&S                                                  0.090726
# host_name_Valeria                                              0.854877
# host_since_19/01/2016                                          0.098638
# host_since_19/08/2016                                          0.846812
# host_since_29/09/2015                                          0.070270
# host_since_30/06/2011                                          0.107865
# host_since_Other                                              -0.690043
# host_location_Healesville, Australia                          -0.032597
# host_location_Melbourne, Australia                            -0.075420
# host_location_Other                                           -0.112953
# host_location_South Yarra, Australia                          -0.013589
# host_location_Victoria, Australia                              0.300796
# host_about_Hello everybody!\r\n\r\nWe aim to ma...             0.103677
# host_about_Hi there! We are Paul and Dan and ru...             0.149772
# host_about_Love cooking, running, playing piano...             0.098638
# host_about_Other                                              -0.150417
# host_about_We specialise in offering a new and ...             0.070386
# host_response_time_within a day                               -0.055155
# host_response_time_within a few hours                          0.205244
# host_response_time_within an hour                             -0.124840
# host_is_superhost_t                                           -0.161943
# host_neighbourhood_Central Business District                  -0.224351
# host_neighbourhood_Other                                      -0.006733
# host_neighbourhood_South Yarra                                 0.003569
# host_neighbourhood_Southbank                                   0.048840
# host_neighbourhood_St Kilda                                   -0.036401
# host_verifications_['email', 'phone']                         -0.296089
# host_verifications_['email']                                  -0.004203
# host_verifications_['phone', 'work_email']                     0.013062
# host_verifications_['phone']                                  -0.006192
# host_has_profile_pic_t                                         0.015179
# host_identity_verified_t                                       0.065159
# neighbourhood_Docklands, Victoria, Australia                  -0.003379
# neighbourhood_Melbourne, Victoria, Australia                   0.032906
# neighbourhood_Other                                           -0.114568
# neighbourhood_South Yarra, Victoria, Australia                -0.011069
# neighbourhood_Southbank, Victoria, Australia                   0.034929
# neighbourhood_cleansed_Other                                  -0.058180
# neighbourhood_cleansed_Port Phillip                            0.012722
# neighbourhood_cleansed_Stonnington                            -0.018959
# neighbourhood_cleansed_Yarra                                  -0.031321
# neighbourhood_cleansed_Yarra Ranges                           -0.085178
# property_type_Entire home                                     -0.036575
# property_type_Entire rental unit                               0.041382
# property_type_Entire serviced apartment                       -0.030098
# property_type_Other                                           -0.122175
# property_type_Private room in home                             0.174331
# room_type_Hotel room                                          -0.012167
# room_type_Private room                                         0.066949
# room_type_Shared room                                         -0.015673
# amenities_["Building staff", "Essentials", "Smo...             0.014986
# amenities_["Essentials", "Smoke alarm", "Hair d...             0.004088
# amenities_["Essentials", "Smoke alarm", "Hot wa...             0.238389
# amenities_["Extra pillows and blankets", "Micro...            -0.006073
# amenities_["Microwave", "Essentials", "Smoke al...             0.039460
# instant_bookable_t                                            -0.035033
# log_price                                                     -0.036011
#
#                                                     latitude  longitude  \
# ID                                                  0.011285   0.013168
# host_response_rate                                  0.004535   0.065148
# host_acceptance_rate                               -0.013115   0.089813
# host_listings_count                                 0.028119  -0.103399
# latitude                                            1.000000   0.032286
# longitude                                           0.032286   1.000000
# accommodates                                        0.023989   0.053354
# bathrooms                                           0.026769   0.028198
# bedrooms                                            0.026625   0.085361
# beds                                                0.023085   0.060233
# minimum_nights                                     -0.005950  -0.040829
# maximum_nights                                      0.007316  -0.027583
# minimum_minimum_nights                             -0.009957  -0.050511
# maximum_minimum_nights                             -0.006711  -0.049737
# minimum_maximum_nights                              0.002645  -0.005166
# maximum_maximum_nights                              0.007257  -0.017333
# minimum_nights_avg_ntm                             -0.008851  -0.052605
# maximum_nights_avg_ntm                              0.007242  -0.017310
# availability_30                                    -0.027358   0.153125
# availability_60                                    -0.028001   0.103391
# availability_90                                    -0.018533   0.105414
# availability_365                                   -0.004089   0.133487
# number_of_reviews                                   0.066783   0.065357
# number_of_reviews_ltm                               0.087145   0.049451
# number_of_reviews_l30d                              0.053466   0.017823
# first_review                                        0.000673   0.025272
# last_review                                        -0.011666   0.016170
# review_scores_rating                                0.014670   0.085317
# review_scores_accuracy                              0.004593   0.082972
# review_scores_cleanliness                           0.000209   0.119926
# review_scores_checkin                               0.004769   0.102372
# review_scores_communication                        -0.001912   0.067287
# review_scores_location                              0.030904   0.058962
# review_scores_value                                -0.004763   0.039818
# calculated_host_listings_count                      0.037220  -0.099714
# calculated_host_listings_count_entire_homes         0.002838  -0.140610
# calculated_host_listings_count_private_rooms        0.049842  -0.047934
# calculated_host_listings_count_shared_rooms         0.003391  -0.032384
# reviews_per_month                                   0.084442   0.064051
# price                                               0.010508   0.006891
# has_gym                                             0.012581  -0.199409
# has_hot_tub                                        -0.002401   0.038487
# days_since_first_review                            -0.006289  -0.006568
# amenities_count                                    -0.018617   0.039253
# years_of_review_activity                           -0.018088   0.011911
# source_previous scrape                             -0.001092  -0.067065
# name_Domi Rentals - The Carlisle Apartments        -0.023262  -0.002018
# name_Large Room in our Lovely Carlton Guest House   0.010557  -0.010759
# name_One Bedroom Apartment                         -0.019212  -0.011649
# name_Other                                          0.002641   0.013456
# name_墨尔本东北区Bundoora温馨独栋别墅，房间干净整齐、设施齐全、交通方便、高速网络...  0.051691   0.004198
# description_Hotel like room for 1 person with e...  0.002514  -0.020301
# description_Hotel like room for 1 person with e...  0.023714  -0.012689
# description_Large and beautiful private room fo...  0.012091  -0.012466
# description_Other                                  -0.010395   0.030115
# description_The moment you step into our apartm...  0.002392  -0.015744
# neighborhood_overview_Melbourne - Voted most li...  0.004949  -0.003104
# neighborhood_overview_Other                        -0.009765   0.012596
# neighborhood_overview_So why not check out Melb...  0.009940  -0.017395
# neighborhood_overview_The best part of the area... -0.004670  -0.024438
# neighborhood_overview_The property is centrally...  0.035980  -0.019268
# host_name_James                                     0.007597  -0.028461
# host_name_Other                                    -0.028154   0.074281
# host_name_Paul & Dan                               -0.007587  -0.037279
# host_name_S&S                                       0.011985  -0.043156
# host_name_Valeria                                   0.050519  -0.048833
# host_since_19/01/2016                               0.006322  -0.037260
# host_since_19/08/2016                               0.051612  -0.048646
# host_since_29/09/2015                              -0.035484   0.011680
# host_since_30/06/2011                              -0.048379  -0.017980
# host_since_Other                                    0.002738   0.063847
# host_location_Healesville, Australia                0.202685   0.244667
# host_location_Melbourne, Australia                  0.013392  -0.091976
# host_location_Other                                -0.066567   0.082895
# host_location_South Yarra, Australia               -0.013174  -0.035205
# host_location_Victoria, Australia                   0.011661  -0.032293
# host_about_Hello everybody!\r\n\r\nWe aim to ma...  0.009572  -0.034577
# host_about_Hi there! We are Paul and Dan and ru... -0.007587  -0.037279
# host_about_Love cooking, running, playing piano...  0.006322  -0.037260
# host_about_Other                                   -0.015883  -0.041000
# host_about_We specialise in offering a new and ...  0.023763   0.064395
# host_response_time_within a day                     0.009279  -0.015505
# host_response_time_within a few hours               0.013455  -0.034297
# host_response_time_within an hour                  -0.011618   0.049289
# host_is_superhost_t                                 0.047599   0.131012
# host_neighbourhood_Central Business District        0.023727   0.267654
# host_neighbourhood_Other                           -0.018143  -0.187287
# host_neighbourhood_South Yarra                     -0.029432  -0.043702
# host_neighbourhood_Southbank                       -0.000430  -0.091710
# host_neighbourhood_St Kilda                        -0.077516  -0.055939
# host_verifications_['email', 'phone']               0.002751   0.087702
# host_verifications_['email']                       -0.037636   0.019096
# host_verifications_['phone', 'work_email']         -0.016158  -0.017431
# host_verifications_['phone']                        0.011152   0.037229
# host_has_profile_pic_t                             -0.011622  -0.024675
# host_identity_verified_t                            0.005915   0.006316
# neighbourhood_Docklands, Victoria, Australia        0.014200  -0.071920
# neighbourhood_Melbourne, Victoria, Australia        0.031447  -0.097232
# neighbourhood_Other                                -0.036735   0.177087
# neighbourhood_South Yarra, Victoria, Australia     -0.028404  -0.045071
# neighbourhood_Southbank, Victoria, Australia        0.002745  -0.085637
# neighbourhood_cleansed_Other                       -0.173611  -0.038371
# neighbourhood_cleansed_Port Phillip                -0.130199  -0.128639
# neighbourhood_cleansed_Stonnington                 -0.067051  -0.049220
# neighbourhood_cleansed_Yarra                        0.072553  -0.071760
# neighbourhood_cleansed_Yarra Ranges                 0.282495   0.769982
# property_type_Entire home                           0.037450   0.138110
# property_type_Entire rental unit                   -0.021750  -0.249458
# property_type_Entire serviced apartment             0.013436  -0.055733
# property_type_Other                                 0.015107   0.174360
# property_type_Private room in home                 -0.036692  -0.034677
# room_type_Hotel room                               -0.018237  -0.000460
# room_type_Private room                             -0.036763  -0.024559
# room_type_Shared room                               0.009115  -0.022741
# amenities_["Building staff", "Essentials", "Smo...  0.008958  -0.015076
# amenities_["Essentials", "Smoke alarm", "Hair d...  0.004270  -0.014799
# amenities_["Essentials", "Smoke alarm", "Hot wa...  0.025333  -0.012601
# amenities_["Extra pillows and blankets", "Micro...  0.004146  -0.011023
# amenities_["Microwave", "Essentials", "Smoke al...  0.000933  -0.016803
# instant_bookable_t                                  0.018436   0.124599
# log_price                                           0.044932   0.140869
#
#                                                     accommodates  bathrooms  \
# ID                                                      0.065331   0.056394
# host_response_rate                                      0.082843   0.030385
# host_acceptance_rate                                    0.118022  -0.057105
# host_listings_count                                    -0.014715   0.190360
# latitude                                                0.023989   0.026769
# longitude                                               0.053354   0.028198
# accommodates                                            1.000000   0.577231
# bathrooms                                               0.577231   1.000000
# bedrooms                                                0.849590   0.626449
# beds                                                    0.876032   0.559891
# minimum_nights                                         -0.013334  -0.008326
# maximum_nights                                          0.080489   0.001208
# minimum_minimum_nights                                 -0.019909  -0.003586
# maximum_minimum_nights                                 -0.001080  -0.008469
# minimum_maximum_nights                                  0.000763  -0.006532
# maximum_maximum_nights                                 -0.018990  -0.021691
# minimum_nights_avg_ntm                                 -0.009426  -0.008450
# maximum_nights_avg_ntm                                 -0.018992  -0.021679
# availability_30                                         0.108196   0.095274
# availability_60                                         0.073818   0.079552
# availability_90                                         0.056538   0.070022
# availability_365                                        0.084863   0.027312
# number_of_reviews                                      -0.026409  -0.115986
# number_of_reviews_ltm                                  -0.000164  -0.085167
# number_of_reviews_l30d                                 -0.053431  -0.095324
# first_review                                           -0.017073   0.000686
# last_review                                            -0.020766   0.003146
# review_scores_rating                                   -0.001453  -0.002143
# review_scores_accuracy                                 -0.006164  -0.006715
# review_scores_cleanliness                              -0.033557  -0.040115
# review_scores_checkin                                  -0.004043   0.004969
# review_scores_communication                             0.009760   0.000619
# review_scores_location                                  0.040220  -0.006023
# review_scores_value                                    -0.040398  -0.030565
# calculated_host_listings_count                         -0.031502   0.195439
# calculated_host_listings_count_entire_homes             0.134314   0.141175
# calculated_host_listings_count_private_rooms           -0.128366   0.181633
# calculated_host_listings_count_shared_rooms            -0.005331  -0.055528
# reviews_per_month                                      -0.003935  -0.092331
# price                                                   0.035625   0.033182
# has_gym                                                 0.033377  -0.032360
# has_hot_tub                                             0.056300   0.062322
# days_since_first_review                                -0.050159  -0.074149
# amenities_count                                         0.235713   0.104874
# ...
# maximum_nights                                                0.062300
# minimum_minimum_nights                                       -0.024488
# maximum_minimum_nights                                       -0.015467
# minimum_maximum_nights                                       -0.006803
# maximum_maximum_nights                                        0.044531
# minimum_nights_avg_ntm                                       -0.025510
# maximum_nights_avg_ntm                                        0.044496
# availability_30                                               0.115166
# availability_60                                               0.088580
# availability_90                                               0.075784
# availability_365                                              0.131279
# number_of_reviews                                            -0.012027
# number_of_reviews_ltm                                         0.013070
# number_of_reviews_l30d                                       -0.018442
# first_review                                                 -0.038959
# last_review                                                  -0.026716
# review_scores_rating                                         -0.051086
# review_scores_accuracy                                       -0.079234
# review_scores_cleanliness                                    -0.049159
# review_scores_checkin                                        -0.074218
# review_scores_communication                                  -0.092876
# review_scores_location                                       -0.044033
# review_scores_value                                          -0.107305
# calculated_host_listings_count                               -0.033676
# calculated_host_listings_count_entire_homes                   0.035531
# calculated_host_listings_count_private_rooms                 -0.071590
# calculated_host_listings_count_shared_rooms                   0.063519
# reviews_per_month                                             0.030777
# price                                                         0.003259
# has_gym                                                       0.021566
# has_hot_tub                                                  -0.005067
# days_since_first_review                                      -0.086616
# amenities_count                                              -0.075507
# years_of_review_activity                                      0.009871
# source_previous scrape                                       -0.007933
# name_Domi Rentals - The Carlisle Apartments                  -0.022582
# name_Large Room in our Lovely Carlton Guest House            -0.016672
# name_One Bedroom Apartment                                    0.020086
# name_Other                                                    0.025518
# name_墨尔本东北区Bundoora温馨独栋别墅，房间干净整齐、设施齐全、交通方便、高速网络...           -0.018009
# description_Hotel like room for 1 person with e...           -0.023097
# description_Hotel like room for 1 person with e...           -0.018009
# description_Large and beautiful private room fo...           -0.019254
# description_Other                                             0.008211
# description_The moment you step into our apartm...            0.051456
# neighborhood_overview_Melbourne - Voted most li...            0.007581
# neighborhood_overview_Other                                  -0.005544
# neighborhood_overview_So why not check out Melb...            0.075780
# neighborhood_overview_The best part of the area...           -0.024698
# neighborhood_overview_The property is centrally...           -0.027245
# host_name_James                                               0.012947
# host_name_Other                                               0.082321
# host_name_Paul & Dan                                         -0.029615
# host_name_S&S                                                -0.048845
# host_name_Valeria                                            -0.073239
# host_since_19/01/2016                                         0.137174
# host_since_19/08/2016                                        -0.073889
# host_since_29/09/2015                                        -0.017507
# host_since_30/06/2011                                         0.146597
# host_since_Other                                             -0.049237
# host_location_Healesville, Australia                          0.075124
# host_location_Melbourne, Australia                            0.022914
# host_location_Other                                          -0.010667
# host_location_South Yarra, Australia                         -0.015321
# host_location_Victoria, Australia                            -0.026778
# host_about_Hello everybody!\r\n\r\nWe aim to ma...           -0.037531
# host_about_Hi there! We are Paul and Dan and ru...           -0.029615
# host_about_Love cooking, running, playing piano...            0.137174
# host_about_Other                                             -0.068275
# host_about_We specialise in offering a new and ...            0.030572
# host_response_time_within a day                              -0.115212
# host_response_time_within a few hours                        -0.184211
# host_response_time_within an hour                             0.237323
# host_is_superhost_t                                          -0.052194
# host_neighbourhood_Central Business District                  0.080876
# host_neighbourhood_Other                                     -0.039422
# host_neighbourhood_South Yarra                               -0.024662
# host_neighbourhood_Southbank                                 -0.017379
# host_neighbourhood_St Kilda                                  -0.020708
# host_verifications_['email', 'phone']                        -0.011488
# host_verifications_['email']                                 -0.006804
# host_verifications_['phone', 'work_email']                    0.011712
# host_verifications_['phone']                                  0.011206
# host_has_profile_pic_t                                        0.012006
# host_identity_verified_t                                     -0.004242
# neighbourhood_Docklands, Victoria, Australia                  0.025408
# neighbourhood_Melbourne, Victoria, Australia                  0.032850
# neighbourhood_Other                                          -0.015314
# neighbourhood_South Yarra, Victoria, Australia                0.005079
# neighbourhood_Southbank, Victoria, Australia                 -0.035073
# neighbourhood_cleansed_Other                                 -0.051437
# neighbourhood_cleansed_Port Phillip                          -0.034241
# neighbourhood_cleansed_Stonnington                           -0.019462
# neighbourhood_cleansed_Yarra                                 -0.005753
# neighbourhood_cleansed_Yarra Ranges                           0.147684
# property_type_Entire home                                    -0.043259
# property_type_Entire rental unit                             -0.034679
# property_type_Entire serviced apartment                       0.149155
# property_type_Other                                           0.068508
# property_type_Private room in home                           -0.076156
# room_type_Hotel room                                          0.095578
# room_type_Private room                                       -0.042351
# room_type_Shared room                                         0.020894
# amenities_["Building staff", "Essentials", "Smo...           -0.020423
# amenities_["Essentials", "Smoke alarm", "Hair d...            0.055583
# amenities_["Essentials", "Smoke alarm", "Hot wa...           -0.020423
# amenities_["Extra pillows and blankets", "Micro...            0.040102
# amenities_["Microwave", "Essentials", "Smoke al...           -0.022582
# instant_bookable_t                                            1.000000
# log_price                                                     0.144305
#
#                                                     log_price
# ID                                                   0.099608
# host_response_rate                                   0.029720
# host_acceptance_rate                                 0.139344
# host_listings_count                                 -0.036011
# latitude                                             0.044932
# longitude                                            0.140869
# accommodates                                         0.569374
# bathrooms                                            0.387547
# bedrooms                                             0.550996
# beds                                                 0.495567
# minimum_nights                                      -0.018875
# maximum_nights                                       0.051502
# minimum_minimum_nights                              -0.027659
# maximum_minimum_nights                               0.005316
# minimum_maximum_nights                               0.013859
# maximum_maximum_nights                               0.031408
# minimum_nights_avg_ntm                              -0.011438
# maximum_nights_avg_ntm                               0.031422
# availability_30                                      0.266149
# availability_60                                      0.212649
# availability_90                                      0.183016
# availability_365                                     0.180303
# number_of_reviews                                   -0.072108
# number_of_reviews_ltm                               -0.034328
# number_of_reviews_l30d                              -0.102681
# first_review                                        -0.006418
# last_review                                          0.009607
# review_scores_rating                                 0.010776
# review_scores_accuracy                               0.015670
# review_scores_cleanliness                            0.041356
# review_scores_checkin                               -0.021113
# review_scores_communication                         -0.008174
# review_scores_location                               0.122273
# review_scores_value                                 -0.084779
# calculated_host_listings_count                      -0.054348
# calculated_host_listings_count_entire_homes          0.118041
# calculated_host_listings_count_private_rooms        -0.150663
# calculated_host_listings_count_shared_rooms         -0.042237
# reviews_per_month                                   -0.029204
# price                                                0.293416
# has_gym                                              0.100134
# has_hot_tub                                          0.083720
# days_since_first_review                             -0.099805
# amenities_count                                      0.179397
# years_of_review_activity                            -0.002560
# source_previous scrape                              -0.062573
# name_Domi Rentals - The Carlisle Apartments          0.032427
# name_Large Room in our Lovely Carlton Guest House   -0.037406
# name_One Bedroom Apartment                           0.017956
# name_Other                                           0.016263
# name_墨尔本东北区Bundoora温馨独栋别墅，房间干净整齐、设施齐全、交通方便、高速网络...  -0.053911
# description_Hotel like room for 1 person with e...  -0.071145
# description_Hotel like room for 1 person with e...  -0.038451
# description_Large and beautiful private room fo...  -0.042931
# description_Other                                    0.076012
# description_The moment you step into our apartm...   0.042482
# neighborhood_overview_Melbourne - Voted most li...   0.014190
# neighborhood_overview_Other                         -0.002290
# neighborhood_overview_So why not check out Melb...  -0.021657
# neighborhood_overview_The best part of the area...  -0.020159
# neighborhood_overview_The property is centrally...  -0.054139
# host_name_James                                      0.009291
# host_name_Other                                      0.080676
# host_name_Paul & Dan                                -0.028767
# host_name_S&S                                       -0.003386
# host_name_Valeria                                   -0.134783
# host_since_19/01/2016                                0.057401
# host_since_19/08/2016                               -0.134830
# host_since_29/09/2015                                0.085551
# host_since_30/06/2011                                0.126186
# host_since_Other                                    -0.012095
# host_location_Healesville, Australia                 0.050682
# host_location_Melbourne, Australia                   0.010665
# host_location_Other                                 -0.012473
# host_location_South Yarra, Australia                -0.020882
# host_location_Victoria, Australia                   -0.004887
# host_about_Hello everybody!\r\n\r\nWe aim to ma...  -0.002409
# host_about_Hi there! We are Paul and Dan and ru...  -0.028767
# host_about_Love cooking, running, playing piano...   0.057401
# host_about_Other                                    -0.000480
# host_about_We specialise in offering a new and ...  -0.026250
# host_response_time_within a day                     -0.024675
# host_response_time_within a few hours               -0.123538
# host_response_time_within an hour                    0.125717
# host_is_superhost_t                                 -0.005193
# host_neighbourhood_Central Business District        -0.043834
# host_neighbourhood_Other                             0.050217
# host_neighbourhood_South Yarra                      -0.010187
# host_neighbourhood_Southbank                         0.128333
# host_neighbourhood_St Kilda                          0.000279
# host_verifications_['email', 'phone']               -0.022167
# host_verifications_['email']                        -0.018816
# host_verifications_['phone', 'work_email']           0.003206
# host_verifications_['phone']                        -0.051485
# host_has_profile_pic_t                              -0.018067
# host_identity_verified_t                             0.072728
# neighbourhood_Docklands, Victoria, Australia         0.064640
# neighbourhood_Melbourne, Victoria, Australia         0.020102
# neighbourhood_Other                                 -0.051060
# neighbourhood_South Yarra, Victoria, Australia      -0.013149
# neighbourhood_Southbank, Victoria, Australia         0.081472
# neighbourhood_cleansed_Other                        -0.221434
# neighbourhood_cleansed_Port Phillip                  0.030794
# neighbourhood_cleansed_Stonnington                  -0.015761
# neighbourhood_cleansed_Yarra                         0.042698
# neighbourhood_cleansed_Yarra Ranges                  0.200488
# property_type_Entire home                            0.316423
# property_type_Entire rental unit                     0.075185
# property_type_Entire serviced apartment              0.095174
# property_type_Other                                 -0.064291
# property_type_Private room in home                  -0.425854
# room_type_Hotel room                                 0.065383
# room_type_Private room                              -0.494894
# room_type_Shared room                               -0.068796
# amenities_["Building staff", "Essentials", "Smo...  -0.020755
# amenities_["Essentials", "Smoke alarm", "Hair d...  -0.021884
# amenities_["Essentials", "Smoke alarm", "Hot wa...  -0.048703
# amenities_["Extra pillows and blankets", "Micro...   0.030371
# amenities_["Microwave", "Essentials", "Smoke al...   0.060021
# instant_bookable_t                                   0.144305
# log_price                                            1.000000
#
# [121 rows x 121 columns]

# %%
import seaborn as sns
# Full correlation matrix
corr_matrix = df_train.corr()

# Top 15 features most correlated with 'log_price'
top_corr_cols = corr_matrix['log_price'].abs().dropna().sort_values(ascending=False).head(15).index

# Extract square matrix for heatmap
top_corr_matrix = corr_matrix.loc[top_corr_cols, top_corr_cols]

# Plot
plt.figure(figsize=(10, 8))
sns.heatmap(top_corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", center=0)
plt.title("Top 15 Correlated Features with log_price")
plt.tight_layout()
plt.show()

# %%
X_train = df_train[['accommodates',
    'bedrooms',
    'beds',
    'bathrooms',
    'availability_30',
    'availability_60',
    'availability_90',
    'availability_365',
    'amenities_count',
    'longitude',
    'host_acceptance_rate',
    'review_scores_location',
    'calculated_host_listings_count_entire_homes',
    'ID',
    'maximum_nights',
    'latitude',
    'review_scores_cleanliness',
    'maximum_nights_avg_ntm',
    'maximum_maximum_nights',
    'host_response_rate',
    'review_scores_accuracy',
    'minimum_maximum_nights',
    'review_scores_rating',
    'maximum_minimum_nights',
    'review_scores_communication',
    'minimum_nights_avg_ntm',
    'minimum_nights',
    'review_scores_checkin',
    'minimum_minimum_nights',
    'reviews_per_month',
    'number_of_reviews_ltm',
    'host_listings_count',
    'calculated_host_listings_count_shared_rooms',
    'calculated_host_listings_count',
    'number_of_reviews',
    'review_scores_value',
    'days_since_first_review',
    'number_of_reviews_l30d',
    'calculated_host_listings_count_private_rooms']]
y_train = df_train['price']

X_test = df_test[['accommodates',
    'bedrooms',
    'beds',
    'bathrooms',
    'availability_30',
    'availability_60',
    'availability_90',
    'availability_365',
    'amenities_count',
    'longitude',
    'host_acceptance_rate',
    'review_scores_location',
    'calculated_host_listings_count_entire_homes',
    'ID',
    'maximum_nights',
    'latitude',
    'review_scores_cleanliness',
    'maximum_nights_avg_ntm',
    'maximum_maximum_nights',
    'host_response_rate',
    'review_scores_accuracy',
    'minimum_maximum_nights',
    'review_scores_rating',
    'maximum_minimum_nights',
    'review_scores_communication',
    'minimum_nights_avg_ntm',
    'minimum_nights',
    'review_scores_checkin',
    'minimum_minimum_nights',
    'reviews_per_month',
    'number_of_reviews_ltm',
    'host_listings_count',
    'calculated_host_listings_count_shared_rooms',
    'calculated_host_listings_count',
    'number_of_reviews',
    'review_scores_value',
    'days_since_first_review',
    'number_of_reviews_l30d',
    'calculated_host_listings_count_private_rooms']]

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Split the training set for evaluation
X_tr, X_val, y_tr, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=40)

# Train and predict (Random Forest)
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=100, random_state=40)
model.fit(X_tr, y_tr)
y_val_pred = model.predict(X_val)

# Evaluate
print("MAE:", mean_absolute_error(y_val, y_val_pred))
# Out:
# MAE: 178.39569285714285

# %%
from sklearn.linear_model import LinearRegression

model1 = LinearRegression()
model1.fit(X_tr, y_tr)
y_pred = model1.predict(X_val)

# Evaluate
print("MAE:", mean_absolute_error(y_val, y_pred))
# Out:
# MAE: 164.08987029993187

# %%
from sklearn.linear_model import Ridge

model2 = Ridge(alpha=1.0)
model2.fit(X_tr, y_tr)
y_pred1 = model2.predict(X_val)

#MAE
print("MAE:", mean_absolute_error(y_val, y_pred1))
# Out:
# MAE: 163.8669472112092
# C:\Users\Jett\anaconda3\Lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=3.4288e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T

# %%
from sklearn.linear_model import Lasso

lasso_model = Lasso(alpha=0.1, random_state=40)
lasso_model.fit(X_tr, y_tr)
lasso_pred = lasso_model.predict(X_val)

print("Lasso Regression")
print("MAE:", mean_absolute_error(y_val, lasso_pred))
# Out:
# Lasso Regression
# MAE: 163.41470534206064
# C:\Users\Jett\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.878e+10, tolerance: 3.779e+06
#   model = cd_fast.enet_coordinate_descent(

# %%
from sklearn.linear_model import ElasticNet

elastic_model = ElasticNet(alpha=0.1, l1_ratio=0.5, random_state=40)
elastic_model.fit(X_tr, y_tr)
elastic_pred = elastic_model.predict(X_val)

print("\n ElasticNet Regression")
print("MAE:", mean_absolute_error(y_val, elastic_pred))
# Out:
#  ElasticNet Regression
# MAE: 153.1881654159082
# C:\Users\Jett\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.879e+10, tolerance: 3.779e+06
#   model = cd_fast.enet_coordinate_descent(

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([214.32, 193.73, 269.5 , ..., 561.88, 268.66, 837.78])

# %% [markdown]
# `(Task 3 - insert more cells as required)`

# %% [markdown]
# ---
# ---
# ## Marking Criteria
#
# To receive full marks your solutions must satisfy the following criteria:
#
# - Problem Description: 9 marks
# - Data Cleaning: 9 marks
# - Building Forecasting models: 9 marks
# - Video Presentation: 3 marks
#     - Duration less than 15 min, presentation skill and content
#     - Each team member delivers a 5-minute presentation on their assigned task
#     - All assignment questions must be discussed on video
#     - Your code must be readable on the video
#     - Discuss both the actions you took and, more importantly, the reasoning behind these actions, explaining the significance of key steps
#     - During the video recording, make sure that both your face and Jupyter Notebook are clearly visible
# - Forecasts correctly uploaded to Kaggle
# - Python code is clean and concise
# - Written explanations are provided in clear and easy to understand sentences
# - The assignment notebook is well-organised and easy to follow
# - Failure to meet the above marking criteria will result in a deduction of marks
#
# ---
# ---
